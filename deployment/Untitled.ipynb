# %%
import pickle

# %%
model = pickle.load(open('model.pkl','rb'))

# %%
model
# Out:
# Pipeline(steps=[('transformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('tnf1', OneHotEncoder(),
#                                                   [1, 3]),
#                                                  ('tnf2', StandardScaler(),
#                                                   [0, 2])])),
#                 ('model', GradientBoostingRegressor(learning_rate=0.5))])

# %%
model.predict([[52,'male',18,'Yes']])
# Out:
# C:\Users\ExcelR\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but OneHotEncoder was fitted with feature names
#   warnings.warn(
# C:\Users\ExcelR\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([28588.28309798])
